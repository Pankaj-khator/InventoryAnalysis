# %%
import requests
import pandas as pd
import time
import urllib

# %%
! pip install lxml

# %%
walmart_sitemap = pd.read_xml('https://raw.githubusercontent.com/Pankaj-khator/InventoryAnalysis/main/Files/walmart_sitemap-category-en0.xml')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 walmart_sitemap = pd.read_xml('https://raw.githubusercontent.com/Pankaj-khator/InventoryAnalysis/main/Files/walmart_sitemap-category-en0.xml')
#
# File /opt/anaconda3/envs/glueviz/lib/python3.11/site-packages/pandas/io/xml.py:1160, in read_xml(path_or_buffer, xpath, namespaces, elems_only, attrs_only, names, dtype, converters, parse_dates, encoding, parser, stylesheet, iterparse, compression, storage_options, dtype_backend)
#     888 r"""
#     889 Read XML document into a :class:`~pandas.DataFrame` object.
#     890
#    (...)
#    1156 1      1  <NA>  4.5  False  b 2019-12-31
#    1157 """
#    1158 check_dtype_backend(dtype_backend)
# -> 1160 return _parse(
#    1161     path_or_buffer=path_or_buffer,
#    1162     xpath=xpath,
#    1163     namespaces=namespaces,
# ...
